# %% [markdown]
# # 🛡️ Anomaly Detection Using ML
# ## 👨‍💻 Abhijit Mahajan

# %% [markdown]
# __📌Import packages :__

# %%
import os
import sys

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

#for loading matlab file
from scipy.io import loadmat

# %% [markdown]
# __📌Import pyod packages :__

# %%
#this all are the anolmaly detection models and mothod
from pyod.models.pca import PCA
from pyod.models.mcd import MCD
from pyod.models.ocsvm import OCSVM
from pyod.models.lof import LOF
from pyod.models.cblof import CBLOF
from pyod.models.knn import KNN
from pyod.models.hbos import HBOS
from pyod.models.abod import ABOD
from pyod.models.iforest import IForest
from pyod.models.feature_bagging import FeatureBagging
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# __📌Import metrics packages :__

# %%
#using this methods we envolving performance of models
from pyod.utils.utility import standardizer 
from pyod.utils.utility import precision_n_scores #measure to identify the performance of model
from sklearn.metrics import roc_auc_score

# %% [markdown]
# __📌How to load mat file :__

# %%
data=loadmat('Dataset/Anamoly_detec_data/cardio.mat')
print(data)
print(">>  __header__ and __version are predifined X and Y define by uer")
print(">>  Length: ",len(data))
print(">>  Keys in MatFile:",data.keys())
print(">>  Type and Independent Var Shape: ",type(data['X']),data['X'].shape)
print(">>  Type and Dependent Var Shape: ",type(data['y']),data['y'].shape)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, written by Octave 3.8.0, 2014-12-18 10:48:09 UTC', '__version__': '1.0', '__globals__': [], 'X': array([[ 0.00491231,  0.69319077, -0.20364049, ...,  0.23149795,
#         -0.28978574, -0.49329397],
#        [ 0.11072935, -0.07990259, -0.20364049, ...,  0.09356344,
#         -0.25638541, -0.49329397],
#        [ 0.21654639, -0.27244466, -0.20364049, ...,  0.02459619,
#         -0.25638541,  1.14001753],
#        ...,
#        [-0.41835583, -0.91998844, -0.16463485, ..., -1.49268341,
#          0.24461959, -0.49329397],
#        [-0.41835583, -0.91998844, -0.15093411, ..., -1.42371616,
#          0.14441859, -0.49329397],
#        [-0.41835583, -0.91998844, -0.20364049, ..., -1.28578165,
#          3.58465295, -0.49329397]]), 'y': array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [1.],
#        [1.],
#        [1.]])}
# >>  __header__ and __version are predifined X and Y define by uer
# >>  Length:  5
# >>  Keys in MatFile: dict_keys(['__header__', '__version__', '__globals__', 'X', 'y'])
# >>  Type and Independent Var Shape:  <class 'numpy.ndarray'> (1831, 21)
# >>  Type and Dependent Var Shape:  <class 'numpy.ndarray'> (1831, 1)

# %% [markdown]
# __📌Define dataset file and read X and y :__

# %%
mat_file_list=['arrhythmia.mat',
              'cardio.mat',
              'glass.mat',
              'ionosphere.mat',
              'letter.mat',
              'lympho.mat',
              'mnist.mat',
              'musk.mat',
              'optdigits.mat',
              'pendigits.mat',
              'pima.mat',
              'satellite.mat',
              'satimage-2.mat',
              'shuttle.mat',
              'vertebral.mat',
              'vowelS.mat',
              'wbc.mat']

#Define nineoutlier detection tools to be compared
df_columns = ['Data','#Samples','# Dimensions', 'Outlier Perc',
              'ABOD','CBLOF','FB','HBOS','IForest','KNN','LOF',
              'MCD','OCSVM','PCA']

from time import time
random_state=np.random.RandomState(42)

# %% [markdown]
# __📌ROC Performance Evolution Table :__

# %%
roc_df=pd.DataFrame(columns=df_columns)
roc_df
# Out:
# Empty DataFrame
# Columns: [Data, #Samples, # Dimensions, Outlier Perc, ABOD, CBLOF, FB, HBOS, IForest, KNN, LOF, MCD, OCSVM, PCA]
# Index: []

# %% [markdown]
# __📌Precision_n_score performance evolution table :__

# %%
prn_df=pd.DataFrame(columns=df_columns)
prn_df
# Out:
# Empty DataFrame
# Columns: [Data, #Samples, # Dimensions, Outlier Perc, ABOD, CBLOF, FB, HBOS, IForest, KNN, LOF, MCD, OCSVM, PCA]
# Index: []

# %% [markdown]
# __📌Time dataframe :__

# %%
time_df=pd.DataFrame(columns=df_columns)
time_df
# Out:
# Empty DataFrame
# Columns: [Data, #Samples, # Dimensions, Outlier Perc, ABOD, CBLOF, FB, HBOS, IForest, KNN, LOF, MCD, OCSVM, PCA]
# Index: []

# %% [markdown]
# __📌Exploring mat files :__

# %%
for mat_file in mat_file_list:
    print("\n...Processing",mat_file)
    mat=loadmat(os.path.join('data',mat_file))
    
    X=mat['X']
    y=mat['y'].ravel()# ravel convert 2 dimension to 1 dimension
    
    outliers_fraction=np.count_nonzero(y)/len(y)
    outliers_percentage=round(outliers_fraction*100,ndigits=4)
    
    #constructing container for saving result
    roc_list=[mat_file[:-1],X.shape[0],X.shape[1],outliers_percentage]
    prn_list=[mat_file[:-1],X.shape[0],X.shape[1],outliers_percentage]
    time_list=[mat_file[:-1],X.shape[0],X.shape[1],outliers_percentage]
    
    #60% training and 40% testing
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=random_state)
    
    
    #standardizing data for processsing
    X_train_norm,X_test_norm=standardizer(X_train,X_test)
    classifiers={'Angle-based Outlier Detector (ABOD)':
                 ABOD(contamination=outliers_fraction),#contamination means on which factor outlier being detected 
                 
                 'Cluster-based Local Outlier Factor (CBLOF)':
                 CBLOF(contamination=outliers_fraction,check_estimator=False),
                 
                 'feature Bagging':
                 FeatureBagging(contamination=outliers_fraction,random_state=random_state),
                 
                 'Histogram-base Outlier Detection(HBOS)':
                 HBOS(contamination=outliers_fraction),
                 
                 'Isolation Forest':
                 IForest(contamination=outliers_fraction,random_state=random_state),
                 
                 'K Nearst Neighbors (KNN)' : 
                 KNN(contamination=outliers_fraction),
                 
                 'Local Outlier Factors(LOF)':
                 LOF(contamination=outliers_fraction),
                 
                 'Minimum Covariance Determination(MCD)':
                 MCD(contamination=outliers_fraction,random_state=random_state),
                 
                 'One Class SVM':
                 OCSVM(contamination=outliers_fraction),
                 
                 'Principle Component Analysis(PCA)':
                 PCA(contamination=outliers_fraction,random_state=random_state),
                
                }
                 
    for clf_name,clf in classifiers.items():
            t0=time()#time before  training
            clf.fit(X_train_norm)#all algo training model here
            test_scores=clf.decision_function(X_test_norm)#test scores of model
            t1=time()#time after training
            duration=round(t1-t0,ndigits=4)#training testing time
            time_list.append(duration) 
            
            roc=round(roc_auc_score(y_test, test_scores),ndigits=4)
            prn=round(precision_n_scores(y_test, test_scores),ndigits=4)
            
            #display all calculation for each algo
            print('{clf_name} ROC:{roc}, precision @ rank n :{prn},'
                  'extecution time :{duration}s'.format(clf_name=clf_name,roc=roc,prn=prn,duration=duration))
           
            roc_list.append(roc)
            prn_list.append(prn)
            
    temp_df = pd.DataFrame(time_list).transpose()
    temp_df.columns=df_columns
    time_df=pd.concat([time_df, temp_df],axis=0)
            
    temp_df = pd.DataFrame(roc_list).transpose()
    temp_df.columns=df_columns
    roc_df=pd.concat([roc_df, temp_df],axis=0)
            
    temp_df = pd.DataFrame(prn_list).transpose()
    temp_df.columns=df_columns
    prn_df=pd.concat([prn_df, temp_df],axis=0)
# Out:
# ...Processing arrhythmia.mat
# Angle-based Outlier Detector (ABOD) ROC:0.7687, precision @ rank n :0.3571,extecution time :12.663s
# Cluster-based Local Outlier Factor (CBLOF) ROC:0.7927, precision @ rank n :0.5,extecution time :15.2883s
# feature Bagging ROC:0.7806, precision @ rank n :0.4643,extecution time :5.0838s
# Histogram-base Outlier Detection(HBOS) ROC:0.8511, precision @ rank n :0.5714,extecution time :13.4449s
# Isolation Forest ROC:0.8527, precision @ rank n :0.5714,extecution time :3.0056s
# K Nearst Neighbors (KNN) ROC:0.782, precision @ rank n :0.5,extecution time :0.6961s
# Local Outlier Factors(LOF) ROC:0.7787, precision @ rank n :0.4643,extecution time :0.586s
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:644: UserWarning: The covariance matrix associated to your dataset is not full rank
#   warnings.warn("The covariance matrix associated to your dataset "
# Minimum Covariance Determination(MCD) ROC:0.8228, precision @ rank n :0.4286,extecution time :6.0658s
# One Class SVM ROC:0.7986, precision @ rank n :0.5,extecution time :0.368s
# Principle Component Analysis(PCA) ROC:0.7997, precision @ rank n :0.5,extecution time :0.456s
#
# ...Processing cardio.mat
# Angle-based Outlier Detector (ABOD) ROC:0.5763, precision @ rank n :0.1875,extecution time :3.5714s
# Cluster-based Local Outlier Factor (CBLOF) ROC:0.7029, precision @ rank n :0.2344,extecution time :1.4483s
# feature Bagging ROC:0.4956, precision @ rank n :0.125,extecution time :5.5535s
# Histogram-base Outlier Detection(HBOS) ROC:0.8453, precision @ rank n :0.4688,extecution time :0.08s
# Isolation Forest ROC:0.9449, precision @ rank n :0.4844,extecution time :3.5529s
# K Nearst Neighbors (KNN) ROC:0.6959, precision @ rank n :0.2812,extecution time :1.2002s
# Local Outlier Factors(LOF) ROC:0.4715, precision @ rank n :0.125,extecution time :0.7525s
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:644: UserWarning: The covariance matrix associated to your dataset is not full rank
#   warnings.warn("The covariance matrix associated to your dataset "
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-151.194010660684711 > -251.293260919606894). You may want to try with a higher value of support_fraction (current value: 0.511).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-151.263449710892274 > -248.704954535017180). You may want to try with a higher value of support_fraction (current value: 0.511).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-152.104566929820152 > -248.938264694146255). You may want to try with a higher value of support_fraction (current value: 0.511).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-151.934464950901173 > -253.644098509254093). You may want to try with a higher value of support_fraction (current value: 0.511).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-156.039898318506005 > -254.457564123663957). You may want to try with a higher value of support_fraction (current value: 0.511).
#   RuntimeWarning)
# Minimum Covariance Determination(MCD) ROC:0.8627, precision @ rank n :0.4219,extecution time :4.2137s
# One Class SVM ROC:0.9507, precision @ rank n :0.5938,extecution time :0.6253s
# Principle Component Analysis(PCA) ROC:0.9638, precision @ rank n :0.6875,extecution time :0.0399s
#
# ...Processing glass.mat
# Angle-based Outlier Detector (ABOD) ROC:0.7104, precision @ rank n :0.25,extecution time :0.384s
# Cluster-based Local Outlier Factor (CBLOF) ROC:0.8506, precision @ rank n :0.25,extecution time :0.3121s
# feature Bagging ROC:0.7439, precision @ rank n :0.25,extecution time :0.2644s
# Histogram-base Outlier Detection(HBOS) ROC:0.6524, precision @ rank n :0.0,extecution time :0.016s
# Isolation Forest ROC:0.7287, precision @ rank n :0.25,extecution time :2.1926s
# K Nearst Neighbors (KNN) ROC:0.7805, precision @ rank n :0.25,extecution time :0.0879s
# Local Outlier Factors(LOF) ROC:0.7774, precision @ rank n :0.25,extecution time :0.016s
# Minimum Covariance Determination(MCD) ROC:0.7165, precision @ rank n :0.0,extecution time :0.2964s
# One Class SVM ROC:0.6189, precision @ rank n :0.25,extecution time :0.008s
# Principle Component Analysis(PCA) ROC:0.622, precision @ rank n :0.25,extecution time :0.016s
#
# ...Processing ionosphere.mat
# Angle-based Outlier Detector (ABOD) ROC:0.9004, precision @ rank n :0.8214,extecution time :0.6093s
# Cluster-based Local Outlier Factor (CBLOF) ROC:0.8855, precision @ rank n :0.8036,extecution time :0.4083s
# feature Bagging ROC:0.8891, precision @ rank n :0.75,extecution time :0.5366s
# Histogram-base Outlier Detection(HBOS) ROC:0.5195, precision @ rank n :0.3393,extecution time :0.072s
# Isolation Forest ROC:0.8315, precision @ rank n :0.6607,extecution time :3.1863s
# K Nearst Neighbors (KNN) ROC:0.9134, precision @ rank n :0.8393,extecution time :0.128s
# Local Outlier Factors(LOF) ROC:0.8989, precision @ rank n :0.75,extecution time :0.0566s
# Minimum Covariance Determination(MCD) ROC:0.9399, precision @ rank n :0.8571,extecution time :0.5738s
# One Class SVM ROC:0.8372, precision @ rank n :0.7143,extecution time :0.048s
# Principle Component Analysis(PCA) ROC:0.7971, precision @ rank n :0.5893,extecution time :0.016s
#
# ...Processing letter.mat
# Angle-based Outlier Detector (ABOD) ROC:0.8465, precision @ rank n :0.275,extecution time :2.5368s
# Cluster-based Local Outlier Factor (CBLOF) ROC:0.7506, precision @ rank n :0.2,extecution time :0.7843s
# feature Bagging ROC:0.8581, precision @ rank n :0.3,extecution time :5.8412s
# Histogram-base Outlier Detection(HBOS) ROC:0.5728, precision @ rank n :0.125,extecution time :0.072s
# Isolation Forest ROC:0.5742, precision @ rank n :0.05,extecution time :2.9933s
# K Nearst Neighbors (KNN) ROC:0.845, precision @ rank n :0.3,extecution time :1.1844s
# Local Outlier Factors(LOF) ROC:0.8409, precision @ rank n :0.325,extecution time :0.7687s
# Minimum Covariance Determination(MCD) ROC:0.7568, precision @ rank n :0.1,extecution time :8.2043s
# One Class SVM ROC:0.5744, precision @ rank n :0.1,extecution time :0.6641s
# Principle Component Analysis(PCA) ROC:0.48, precision @ rank n :0.05,extecution time :0.048s
#
# ...Processing lympho.mat
# Angle-based Outlier Detector (ABOD) ROC:0.8304, precision @ rank n :0.3333,extecution time :0.2241s
# Cluster-based Local Outlier Factor (CBLOF) ROC:0.9123, precision @ rank n :0.6667,extecution time :0.3164s
# feature Bagging ROC:0.9474, precision @ rank n :0.6667,extecution time :0.232s
# Histogram-base Outlier Detection(HBOS) ROC:0.9942, precision @ rank n :0.6667,extecution time :0.04s
# Isolation Forest ROC:0.9649, precision @ rank n :0.6667,extecution time :2.088s
# K Nearst Neighbors (KNN) ROC:0.9415, precision @ rank n :0.6667,extecution time :0.0564s
# Local Outlier Factors(LOF) ROC:0.9415, precision @ rank n :0.6667,extecution time :0.024s
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-303.345484320709943 > -338.267336074836066). You may want to try with a higher value of support_fraction (current value: 0.614).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-301.940741696840234 > -334.895981708824650). You may want to try with a higher value of support_fraction (current value: 0.614).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-304.038124824529348 > -306.387507397201887). You may want to try with a higher value of support_fraction (current value: 0.614).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-371.875143374065829 > -374.780100167854414). You may want to try with a higher value of support_fraction (current value: 0.614).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-517.131493325082488 > -664.271030825227399). You may want to try with a higher value of support_fraction (current value: 0.614).
#   RuntimeWarning)
# Minimum Covariance Determination(MCD) ROC:0.9357, precision @ rank n :0.6667,extecution time :0.28s
# One Class SVM ROC:0.9532, precision @ rank n :0.6667,extecution time :0.016s
# Principle Component Analysis(PCA) ROC:0.9591, precision @ rank n :0.6667,extecution time :0.016s
#
# ...Processing mnist.mat
# Angle-based Outlier Detector (ABOD) ROC:0.7708, precision @ rank n :0.35,extecution time :54.5005s
# Cluster-based Local Outlier Factor (CBLOF) ROC:0.854, precision @ rank n :0.4107,extecution time :7.1044s
# feature Bagging ROC:0.6872, precision @ rank n :0.3036,extecution time :344.2075s
# Histogram-base Outlier Detection(HBOS) ROC:0.5679, precision @ rank n :0.1214,extecution time :0.48s
# Isolation Forest ROC:0.7999, precision @ rank n :0.2714,extecution time :14.3032s
# K Nearst Neighbors (KNN) ROC:0.8403, precision @ rank n :0.4,extecution time :49.513s
# Local Outlier Factors(LOF) ROC:0.6905, precision @ rank n :0.3071,extecution time :47.5837s
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:644: UserWarning: The covariance matrix associated to your dataset is not full rank
#   warnings.warn("The covariance matrix associated to your dataset "
# Minimum Covariance Determination(MCD) ROC:0.8454, precision @ rank n :0.2,extecution time :18.8947s
# One Class SVM ROC:0.8586, precision @ rank n :0.3893,extecution time :35.2252s
# Principle Component Analysis(PCA) ROC:0.8555, precision @ rank n :0.3679,extecution time :0.9881s
#
# ...Processing musk.mat
# Angle-based Outlier Detector (ABOD) ROC:0.1139, precision @ rank n :0.0312,extecution time :16.2573s
# Cluster-based Local Outlier Factor (CBLOF) ROC:1.0, precision @ rank n :1.0,extecution time :2.4496s
# feature Bagging ROC:0.6284, precision @ rank n :0.3438,extecution time :88.1617s
# Histogram-base Outlier Detection(HBOS) ROC:1.0, precision @ rank n :0.9688,extecution time :0.504s
# Isolation Forest ROC:0.9998, precision @ rank n :0.9375,extecution time :8.8446s
# K Nearst Neighbors (KNN) ROC:0.7694, precision @ rank n :0.2812,extecution time :13.3421s
# Local Outlier Factors(LOF) ROC:0.6308, precision @ rank n :0.1875,extecution time :12.9942s
# Minimum Covariance Determination(MCD) ROC:0.9997, precision @ rank n :0.9375,extecution time :75.9832s
# One Class SVM ROC:1.0, precision @ rank n :1.0,extecution time :9.3187s
# Principle Component Analysis(PCA) ROC:1.0, precision @ rank n :0.9688,extecution time :1.1041s
#
# ...Processing optdigits.mat
# Angle-based Outlier Detector (ABOD) ROC:0.4428, precision @ rank n :0.0161,extecution time :18.4897s
# Cluster-based Local Outlier Factor (CBLOF) ROC:0.7718, precision @ rank n :0.0,extecution time :3.9236s
# feature Bagging ROC:0.4715, precision @ rank n :0.0484,extecution time :103.1325s
# Histogram-base Outlier Detection(HBOS) ROC:0.8822, precision @ rank n :0.2581,extecution time :0.264s
# Isolation Forest ROC:0.5714, precision @ rank n :0.0161,extecution time :6.4913s
# K Nearst Neighbors (KNN) ROC:0.3824, precision @ rank n :0.0,extecution time :13.7271s
# Local Outlier Factors(LOF) ROC:0.4584, precision @ rank n :0.0484,extecution time :12.4292s
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:644: UserWarning: The covariance matrix associated to your dataset is not full rank
#   warnings.warn("The covariance matrix associated to your dataset "
# Minimum Covariance Determination(MCD) ROC:0.3674, precision @ rank n :0.0,extecution time :8.5202s
# One Class SVM ROC:0.4972, precision @ rank n :0.0,extecution time :10.592s
# Principle Component Analysis(PCA) ROC:0.504, precision @ rank n :0.0,extecution time :0.384s
#
# ...Processing pendigits.mat
# Angle-based Outlier Detector (ABOD) ROC:0.7028, precision @ rank n :0.0606,extecution time :11.5995s
# Cluster-based Local Outlier Factor (CBLOF) ROC:0.8508, precision @ rank n :0.197,extecution time :1.9286s
# feature Bagging ROC:0.4582, precision @ rank n :0.0606,extecution time :31.1362s
# Histogram-base Outlier Detection(HBOS) ROC:0.9284, precision @ rank n :0.2879,extecution time :0.064s
# Isolation Forest ROC:0.9563, precision @ rank n :0.3939,extecution time :5.5443s
# K Nearst Neighbors (KNN) ROC:0.7678, precision @ rank n :0.0909,extecution time :5.1769s
# Local Outlier Factors(LOF) ROC:0.4507, precision @ rank n :0.0758,extecution time :5.2009s
# Minimum Covariance Determination(MCD) ROC:0.8302, precision @ rank n :0.0606,extecution time :22.3748s
# One Class SVM ROC:0.9333, precision @ rank n :0.303,extecution time :8.8s
# Principle Component Analysis(PCA) ROC:0.9341, precision @ rank n :0.3485,extecution time :0.2s
#
# ...Processing pima.mat
# Angle-based Outlier Detector (ABOD) ROC:0.7082, precision @ rank n :0.5545,extecution time :3.9274s
# Cluster-based Local Outlier Factor (CBLOF) ROC:0.6667, precision @ rank n :0.495,extecution time :1.12s
# feature Bagging ROC:0.6413, precision @ rank n :0.4455,extecution time :1.1204s
# Histogram-base Outlier Detection(HBOS) ROC:0.6997, precision @ rank n :0.5446,extecution time :0.04s
# Isolation Forest ROC:0.6524, precision @ rank n :0.4851,extecution time :5.1033s
# K Nearst Neighbors (KNN) ROC:0.7207, precision @ rank n :0.5248,extecution time :0.672s
# Local Outlier Factors(LOF) ROC:0.6513, precision @ rank n :0.4554,extecution time :0.184s
# Minimum Covariance Determination(MCD) ROC:0.6591, precision @ rank n :0.4851,extecution time :1.408s
# One Class SVM ROC:0.5965, precision @ rank n :0.4455,extecution time :0.104s
# Principle Component Analysis(PCA) ROC:0.6373, precision @ rank n :0.4752,extecution time :0.016s
#
# ...Processing satellite.mat
# Angle-based Outlier Detector (ABOD) ROC:0.5588, precision @ rank n :0.4063,extecution time :24.0283s
# Cluster-based Local Outlier Factor (CBLOF) ROC:0.7276, precision @ rank n :0.5623,extecution time :6.4705s
# feature Bagging ROC:0.5361, precision @ rank n :0.3894,extecution time :74.8469s
# Histogram-base Outlier Detection(HBOS) ROC:0.745, precision @ rank n :0.5671,extecution time :0.2254s
# Isolation Forest ROC:0.6898, precision @ rank n :0.5345,extecution time :10.8899s
# K Nearst Neighbors (KNN) ROC:0.6757, precision @ rank n :0.4861,extecution time :11.3008s
# Local Outlier Factors(LOF) ROC:0.5408, precision @ rank n :0.3906,extecution time :10.4745s
# Minimum Covariance Determination(MCD) ROC:0.7888, precision @ rank n :0.6687,extecution time :28.3543s
# One Class SVM ROC:0.6564, precision @ rank n :0.5357,extecution time :13.1243s
# Principle Component Analysis(PCA) ROC:0.5936, precision @ rank n :0.48,extecution time :0.2449s
#
# ...Processing satimage-2.mat
# Angle-based Outlier Detector (ABOD) ROC:0.8701, precision @ rank n :0.2857,extecution time :22.8553s
# Cluster-based Local Outlier Factor (CBLOF) ROC:1.0, precision @ rank n :1.0,extecution time :3.9118s
# feature Bagging ROC:0.3653, precision @ rank n :0.0714,extecution time :61.3293s
# Histogram-base Outlier Detection(HBOS) ROC:0.9959, precision @ rank n :0.75,extecution time :0.1947s
# Isolation Forest ROC:0.9999, precision @ rank n :0.9643,extecution time :8.4397s
# K Nearst Neighbors (KNN) ROC:0.9452, precision @ rank n :0.4286,extecution time :9.6836s
# Local Outlier Factors(LOF) ROC:0.3646, precision @ rank n :0.0714,extecution time :6.0715s
# Minimum Covariance Determination(MCD) ROC:0.9955, precision @ rank n :0.6071,extecution time :17.1652s
# One Class SVM ROC:1.0, precision @ rank n :1.0,extecution time :10.9s
# Principle Component Analysis(PCA) ROC:0.9979, precision @ rank n :0.8929,extecution time :0.2802s
#
# ...Processing shuttle.mat
# Angle-based Outlier Detector (ABOD) ROC:0.6194, precision @ rank n :0.1958,extecution time :160.8743s
# Cluster-based Local Outlier Factor (CBLOF) ROC:0.5813, precision @ rank n :0.2627,extecution time :8.4026s
# feature Bagging ROC:0.4543, precision @ rank n :0.0627,extecution time :453.0915s
# Histogram-base Outlier Detection(HBOS) ROC:0.9879, precision @ rank n :0.994,extecution time :0.1431s
# Isolation Forest ROC:0.9982, precision @ rank n :0.9704,extecution time :26.8012s
# K Nearst Neighbors (KNN) ROC:0.6454, precision @ rank n :0.208,extecution time :79.6778s
# Local Outlier Factors(LOF) ROC:0.5336, precision @ rank n :0.1338,extecution time :101.2171s
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-48.478585313883094 > -72.674902791827449). You may want to try with a higher value of support_fraction (current value: 0.503).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.020932920545206 > -77.273778830366624). You may want to try with a higher value of support_fraction (current value: 0.503).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.773186737374203 > -77.627442643730902). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.567736687928168 > -77.149693502219407). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.558014061389130 > -77.305474497250813). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.447184144690226 > -80.045122667876768). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.831341712300798 > -77.545650836952845). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.720921660808528 > -76.030899900482609). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.220789136851664 > -75.972686639612149). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.384303993340097 > -79.016753514660920). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.865432948298562 > -78.922690635276169). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.722720515133283 > -77.249651024727655). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.837836562575120 > -77.367293537845569). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.900412860944741 > -77.343288252105793). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.447062535731902 > -117.039548690382944). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.746912160353510 > -80.259138508220943). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.210525779001983 > -77.176341690742774). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.139907389877912 > -116.032331129271043). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.339037169972499 > -116.286306865603493). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.437509514062029 > -116.987037643597588). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.374313365347476 > -116.546884565200372). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.203633222550245 > -115.352175594478169). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.422536086659129 > -116.675898101053946). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.336251543852590 > -116.248160266387529). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.528424930653173 > -115.501719959400461). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.430269794629368 > -117.034104968305229). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.799085150582584 > -76.146367964106986). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.276491114543425 > -78.256405047937037). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.820328600727251 > -79.163602521159177). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.085501578409549 > -81.069111191154406). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.657983987123593 > -77.596011287705281). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.251653535798809 > -78.044049146717597). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.172239851971277 > -78.853606176268940). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.924692680059081 > -76.717789278381730). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.892080032412252 > -75.855884916932993). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.443292162313760 > -117.037783423484186). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.447210964850235 > -117.035443379215934). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.720445845270348 > -76.698938364955794). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.638905506770634 > -76.429460576927326). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.109903867071566 > -74.633047853245245). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.271280930525023 > -76.792145992395490). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.792774479823812 > -76.074022603262435). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.089860377674462 > -78.905319249409388). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.784456952042703 > -76.672161170851780). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.752137193041015 > -75.783363932252641). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.378261297803874 > -77.231009989574090). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.382959783759723 > -78.473340549249926). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.579600042106527 > -78.784858455031156). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.327721858163379 > -75.639486745464950). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.257219551655609 > -79.053105427554954). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.357518117189784 > -75.513977532701759). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.637624625150750 > -77.948644346352310). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.257902405253155 > -76.900607751753853). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.759764511871730 > -76.614212501611533). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.946815199396127 > -77.923474441204917). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.795666243710102 > -77.302089429728241). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.164868798444999 > -76.284581385896985). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.428359014368475 > -116.915385230075671). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.088348216399318 > -75.909975721006973). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.343002222991188 > -78.730948064420232). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# Minimum Covariance Determination(MCD) ROC:0.9898, precision @ rank n :0.7359,extecution time :125.4108s
# One Class SVM ROC:0.9936, precision @ rank n :0.9585,extecution time :379.6533s
# Principle Component Analysis(PCA) ROC:0.992, precision @ rank n :0.9535,extecution time :0.3099s
#
# ...Processing vertebral.mat
# Angle-based Outlier Detector (ABOD) ROC:0.3812, precision @ rank n :0.0625,extecution time :0.3295s
# Cluster-based Local Outlier Factor (CBLOF) ROC:0.4469, precision @ rank n :0.125,extecution time :0.4435s
# feature Bagging ROC:0.3781, precision @ rank n :0.0,extecution time :0.409s
# Histogram-base Outlier Detection(HBOS) ROC:0.3555, precision @ rank n :0.0625,extecution time :0.0207s
# Isolation Forest ROC:0.4039, precision @ rank n :0.0625,extecution time :2.6012s
# K Nearst Neighbors (KNN) ROC:0.3797, precision @ rank n :0.0,extecution time :0.0879s
# Local Outlier Factors(LOF) ROC:0.3844, precision @ rank n :0.0,extecution time :0.0281s
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-23.850119172732221 > -42.327379211673687). You may want to try with a higher value of support_fraction (current value: 0.528).
#   RuntimeWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-23.888885887470039 > -42.394136109163640). You may want to try with a higher value of support_fraction (current value: 0.528).
#   RuntimeWarning)
# Minimum Covariance Determination(MCD) ROC:0.3742, precision @ rank n :0.0,extecution time :0.3407s
# One Class SVM ROC:0.4547, precision @ rank n :0.0625,extecution time :0.016s
# Principle Component Analysis(PCA) ROC:0.4875, precision @ rank n :0.1875,extecution time :0.008s
#
# ...Processing vowelS.mat
# Angle-based Outlier Detector (ABOD) ROC:0.9165, precision @ rank n :0.5,extecution time :2.2891s
# Cluster-based Local Outlier Factor (CBLOF) ROC:0.8927, precision @ rank n :0.1667,extecution time :0.9998s
# feature Bagging ROC:0.9396, precision @ rank n :0.1667,extecution time :2.4152s
# Histogram-base Outlier Detection(HBOS) ROC:0.681, precision @ rank n :0.0556,extecution time :0.035s
# Isolation Forest ROC:0.7428, precision @ rank n :0.2778,extecution time :3.1501s
# K Nearst Neighbors (KNN) ROC:0.9796, precision @ rank n :0.5,extecution time :0.7347s
# Local Outlier Factors(LOF) ROC:0.9479, precision @ rank n :0.3333,extecution time :0.2732s
# Minimum Covariance Determination(MCD) ROC:0.8655, precision @ rank n :0.1667,extecution time :6.7099s
# One Class SVM ROC:0.7525, precision @ rank n :0.2778,extecution time :0.331s
# Principle Component Analysis(PCA) ROC:0.5779, precision @ rank n :0.1111,extecution time :0.0181s
#
# ...Processing wbc.mat
# Angle-based Outlier Detector (ABOD) ROC:0.8847, precision @ rank n :0.3333,extecution time :0.691s
# Cluster-based Local Outlier Factor (CBLOF) ROC:0.9007, precision @ rank n :0.3333,extecution time :0.4466s
# feature Bagging ROC:0.9361, precision @ rank n :0.5,extecution time :0.6447s
# Histogram-base Outlier Detection(HBOS) ROC:0.9338, precision @ rank n :0.5,extecution time :0.0704s
# Isolation Forest ROC:0.9235, precision @ rank n :0.5,extecution time :2.7471s
# K Nearst Neighbors (KNN) ROC:0.9201, precision @ rank n :0.5,extecution time :0.1577s
# Local Outlier Factors(LOF) ROC:0.9372, precision @ rank n :0.5,extecution time :0.0728s
# Minimum Covariance Determination(MCD) ROC:0.8893, precision @ rank n :0.3333,extecution time :0.9406s
# One Class SVM ROC:0.9269, precision @ rank n :0.5,extecution time :0.0535s
# Principle Component Analysis(PCA) ROC:0.9053, precision @ rank n :0.5,extecution time :0.0302s

# %% [markdown]
# __📌 Lets Analyze Output :__

# %%
roc_df
# Out:
#             Data #Samples # Dimensions Outlier Perc    ABOD   CBLOF      FB  \
# 0  arrhythmia.ma      452          274      14.6018  0.7687  0.7927  0.7806
# 0      cardio.ma     1831           21       9.6122  0.5763  0.7029  0.4956
# 0       glass.ma      214            9       4.2056  0.7104  0.8506  0.7439
# 0  ionosphere.ma      351           33      35.8974  0.9004  0.8855  0.8891
# 0      letter.ma     1600           32         6.25  0.8465  0.7506  0.8581
# 0      lympho.ma      148           18       4.0541  0.8304  0.9123  0.9474
# 0       mnist.ma     7603          100       9.2069  0.7708   0.854  0.6872
# 0        musk.ma     3062          166       3.1679  0.1139       1  0.6284
# 0   optdigits.ma     5216           64       2.8758  0.4428  0.7718  0.4715
# 0   pendigits.ma     6870           16       2.2707  0.7028  0.8508  0.4582
# 0        pima.ma      768            8      34.8958  0.7082  0.6667  0.6413
# 0   satellite.ma     6435           36      31.6395  0.5588  0.7276  0.5361
# 0  satimage-2.ma     5803           36       1.2235  0.8701       1  0.3653
# 0     shuttle.ma    49097            9       7.1511  0.6194  0.5813  0.4543
# 0   vertebral.ma      240            6         12.5  0.3812  0.4469  0.3781
# 0      vowelS.ma     1456           12       3.4341  0.9165  0.8927  0.9396
# 0         wbc.ma      378           30       5.5556  0.8847  0.9007  0.9361
#
#      HBOS IForest     KNN     LOF     MCD   OCSVM     PCA
# 0  0.8511  0.8527   0.782  0.7787  0.8228  0.7986  0.7997
# 0  0.8453  0.9449  0.6959  0.4715  0.8627  0.9507  0.9638
# 0  0.6524  0.7287  0.7805  0.7774  0.7165  0.6189   0.622
# 0  0.5195  0.8315  0.9134  0.8989  0.9399  0.8372  0.7971
# 0  0.5728  0.5742   0.845  0.8409  0.7568  0.5744    0.48
# 0  0.9942  0.9649  0.9415  0.9415  0.9357  0.9532  0.9591
# 0  0.5679  0.7999  0.8403  0.6905  0.8454  0.8586  0.8555
# 0       1  0.9998  0.7694  0.6308  0.9997       1       1
# 0  0.8822  0.5714  0.3824  0.4584  0.3674  0.4972   0.504
# 0  0.9284  0.9563  0.7678  0.4507  0.8302  0.9333  0.9341
# 0  0.6997  0.6524  0.7207  0.6513  0.6591  0.5965  0.6373
# 0   0.745  0.6898  0.6757  0.5408  0.7888  0.6564  0.5936
# 0  0.9959  0.9999  0.9452  0.3646  0.9955       1  0.9979
# 0  0.9879  0.9982  0.6454  0.5336  0.9898  0.9936   0.992
# 0  0.3555  0.4039  0.3797  0.3844  0.3742  0.4547  0.4875
# 0   0.681  0.7428  0.9796  0.9479  0.8655  0.7525  0.5779
# 0  0.9338  0.9235  0.9201  0.9372  0.8893  0.9269  0.9053

# %%
prn_df
# Out:
#             Data #Samples # Dimensions Outlier Perc    ABOD   CBLOF      FB  \
# 0  arrhythmia.ma      452          274      14.6018  0.3571     0.5  0.4643
# 0      cardio.ma     1831           21       9.6122  0.1875  0.2344   0.125
# 0       glass.ma      214            9       4.2056    0.25    0.25    0.25
# 0  ionosphere.ma      351           33      35.8974  0.8214  0.8036    0.75
# 0      letter.ma     1600           32         6.25   0.275     0.2     0.3
# 0      lympho.ma      148           18       4.0541  0.3333  0.6667  0.6667
# 0       mnist.ma     7603          100       9.2069    0.35  0.4107  0.3036
# 0        musk.ma     3062          166       3.1679  0.0312       1  0.3438
# 0   optdigits.ma     5216           64       2.8758  0.0161       0  0.0484
# 0   pendigits.ma     6870           16       2.2707  0.0606   0.197  0.0606
# 0        pima.ma      768            8      34.8958  0.5545   0.495  0.4455
# 0   satellite.ma     6435           36      31.6395  0.4063  0.5623  0.3894
# 0  satimage-2.ma     5803           36       1.2235  0.2857       1  0.0714
# 0     shuttle.ma    49097            9       7.1511  0.1958  0.2627  0.0627
# 0   vertebral.ma      240            6         12.5  0.0625   0.125       0
# 0      vowelS.ma     1456           12       3.4341     0.5  0.1667  0.1667
# 0         wbc.ma      378           30       5.5556  0.3333  0.3333     0.5
#
#      HBOS IForest     KNN     LOF     MCD   OCSVM     PCA
# 0  0.5714  0.5714     0.5  0.4643  0.4286     0.5     0.5
# 0  0.4688  0.4844  0.2812   0.125  0.4219  0.5938  0.6875
# 0       0    0.25    0.25    0.25       0    0.25    0.25
# 0  0.3393  0.6607  0.8393    0.75  0.8571  0.7143  0.5893
# 0   0.125    0.05     0.3   0.325     0.1     0.1    0.05
# 0  0.6667  0.6667  0.6667  0.6667  0.6667  0.6667  0.6667
# 0  0.1214  0.2714     0.4  0.3071     0.2  0.3893  0.3679
# 0  0.9688  0.9375  0.2812  0.1875  0.9375       1  0.9688
# 0  0.2581  0.0161       0  0.0484       0       0       0
# 0  0.2879  0.3939  0.0909  0.0758  0.0606   0.303  0.3485
# 0  0.5446  0.4851  0.5248  0.4554  0.4851  0.4455  0.4752
# 0  0.5671  0.5345  0.4861  0.3906  0.6687  0.5357    0.48
# 0    0.75  0.9643  0.4286  0.0714  0.6071       1  0.8929
# 0   0.994  0.9704   0.208  0.1338  0.7359  0.9585  0.9535
# 0  0.0625  0.0625       0       0       0  0.0625  0.1875
# 0  0.0556  0.2778     0.5  0.3333  0.1667  0.2778  0.1111
# 0     0.5     0.5     0.5     0.5  0.3333     0.5     0.5

# %%
time_df
# Out:
#             Data #Samples # Dimensions Outlier Perc     ABOD    CBLOF  \
# 0  arrhythmia.ma      452          274      14.6018   12.663  15.2883
# 0      cardio.ma     1831           21       9.6122   3.5714   1.4483
# 0       glass.ma      214            9       4.2056    0.384   0.3121
# 0  ionosphere.ma      351           33      35.8974   0.6093   0.4083
# 0      letter.ma     1600           32         6.25   2.5368   0.7843
# 0      lympho.ma      148           18       4.0541   0.2241   0.3164
# 0       mnist.ma     7603          100       9.2069  54.5005   7.1044
# 0        musk.ma     3062          166       3.1679  16.2573   2.4496
# 0   optdigits.ma     5216           64       2.8758  18.4897   3.9236
# 0   pendigits.ma     6870           16       2.2707  11.5995   1.9286
# 0        pima.ma      768            8      34.8958   3.9274     1.12
# 0   satellite.ma     6435           36      31.6395  24.0283   6.4705
# 0  satimage-2.ma     5803           36       1.2235  22.8553   3.9118
# 0     shuttle.ma    49097            9       7.1511  160.874   8.4026
# 0   vertebral.ma      240            6         12.5   0.3295   0.4435
# 0      vowelS.ma     1456           12       3.4341   2.2891   0.9998
# 0         wbc.ma      378           30       5.5556    0.691   0.4466
#
#         FB     HBOS  IForest      KNN      LOF      MCD    OCSVM     PCA
# 0   5.0838  13.4449   3.0056   0.6961    0.586   6.0658    0.368   0.456
# 0   5.5535     0.08   3.5529   1.2002   0.7525   4.2137   0.6253  0.0399
# 0   0.2644    0.016   2.1926   0.0879    0.016   0.2964    0.008   0.016
# 0   0.5366    0.072   3.1863    0.128   0.0566   0.5738    0.048   0.016
# 0   5.8412    0.072   2.9933   1.1844   0.7687   8.2043   0.6641   0.048
# 0    0.232     0.04    2.088   0.0564    0.024     0.28    0.016   0.016
# 0  344.207     0.48  14.3032   49.513  47.5837  18.8947  35.2252  0.9881
# 0  88.1617    0.504   8.8446  13.3421  12.9942  75.9832   9.3187  1.1041
# 0  103.132    0.264   6.4913  13.7271  12.4292   8.5202   10.592   0.384
# 0  31.1362    0.064   5.5443   5.1769   5.2009  22.3748      8.8     0.2
# 0   1.1204     0.04   5.1033    0.672    0.184    1.408    0.104   0.016
# 0  74.8469   0.2254  10.8899  11.3008  10.4745  28.3543  13.1243  0.2449
# 0  61.3293   0.1947   8.4397   9.6836   6.0715  17.1652     10.9  0.2802
# 0  453.091   0.1431  26.8012  79.6778  101.217  125.411  379.653  0.3099
# 0    0.409   0.0207   2.6012   0.0879   0.0281   0.3407    0.016   0.008
# 0   2.4152    0.035   3.1501   0.7347   0.2732   6.7099    0.331  0.0181
# 0   0.6447   0.0704   2.7471   0.1577   0.0728   0.9406   0.0535  0.0302

# %% [markdown]
# # 🔜
# __Next Module Anonaly Point Detection and Correction will coming soon...__
